# %%
import rclpy

from rclpy.node import Node

from sensor_msgs.msg import LaserScan
from geometry_msgs.msg import Twist

class Roamer(Node):

    def __init__(self):
        super().__init__('roamer')
        self.laser_sub = self.create_subscription(
            LaserScan,"/scan",
            self.callback, 1)
        self.twist_pub = self.create_publisher(
            Twist,
            '/cmd_vel', 1)

    def callback(self, data):
        min_range = data.range_max
        print(len(data.ranges))
        for v in data.ranges:
            if v < min_range:
                min_range = v
        print(min_range)
        twist = Twist()
        if min_range < 1.0:
            twist.angular.z = 1.0
        else:
            twist.linear.x = 0.2
        self.twist_pub.publish(twist)
            
        

try:
    rclpy.init()
    node = Roamer()
    rclpy.spin(node)
finally:
    try:
        node.destroy_node()
    finally: 
        rclpy.shutdown()
# Out:
# 360
# 0.12292923778295517
# 360
# 0.3030383586883545
# 360
# 0.12402196228504181
# 360
# 0.1621476113796234
# 360
# 0.28943967819213867
# 360
# 0.292533814907074
# 360
# 0.13996075093746185
# 360
# 0.13453587889671326
# 360
# 0.2968338429927826
# 360
# 0.16107416152954102
# 360
# 0.1514740288257599
# 360
# 0.14348387718200684
# 360
# 0.32854604721069336
# 360
# 0.13628892600536346
# 360
# 0.34457501769065857
# 360
# 0.3487904965877533
# 360
# 0.12794029712677002
# 360
# 0.37731483578681946
# 360
# 0.13395485281944275
# 360
# 0.13022273778915405
# 360
# 0.37071606516838074
# 360
# 0.38602906465530396
# 360
# 0.13242830336093903
# 360
# 0.18701085448265076
# 360
# 0.3587457835674286
# 360
# 0.12914513051509857
# 360
# 0.34381791949272156
# 360
# 0.3408563435077667
# 360
# 0.34980636835098267
# 360
# 0.14607740938663483
# 360
# 0.3100656270980835
# 360
# 0.30369341373443604
# 360
# 0.3203093409538269
# 360
# 0.12142185121774673
# 360
# 0.11999999731779099
# 360
# 0.1730084866285324
# 360
# 0.19108760356903076
# 360
# 0.1402977854013443
# 360
# 0.13462769985198975
# 360
# 0.13108566403388977
# 360
# 0.11999999731779099
# 360
# 0.12205621600151062
# 360
# 0.17816215753555298
# 360
# 0.12031614035367966
# 360
# 0.14769692718982697
# 360
# 0.11999999731779099
# 360
# 0.11999999731779099
# 360
# 0.13178786635398865
# 360
# 0.11999999731779099
# 360
# 0.11999999731779099
# 360
# 0.15398436784744263
# 360
# 0.11999999731779099
# 360
# 0.11999999731779099
# 360
# 0.15787552297115326
# 360
# 0.11999999731779099
# 360
# 0.1319303661584854
# 360
# 0.3117828071117401
# 360
# 0.17092716693878174
# 360
# 0.1400754749774933
# 360
# 0.11999999731779099
# 360
# 0.11999999731779099
# 360
# 0.3150227963924408
# 360
# 0.13110429048538208
# 360
# 0.11999999731779099
# 360
# 0.12452588230371475
# 360
# 0.15788666903972626
# 360
# 0.11999999731779099
# 360
# 0.14219780266284943
# 360
# 0.11999999731779099
# 360
# 0.11999999731779099
# 360
# 0.11999999731779099
# 360
# 0.14333376288414001
# 360
# 0.12813138961791992
# 360
# 0.16163048148155212
# 360
# 0.11999999731779099
# 360
# 0.11999999731779099
# 360
# 0
# 0.11999999731779099
# 360
# 0.16104251146316528
# 360
# 0.3391861319541931
# 360
# 0.33666786551475525
# 360
# 0.16973057389259338
# 360
# 0.3565577566623688
# 360
# 0.12981773912906647
# 360
# 0.36981871724128723
# 360
# 0.3888232111930847
# 360
# 0.3931247889995575
# 360
# 0.39908525347709656
# 360
# 0.410724937915802
# 360
# 0.14617355167865753
# 360
# 0.12039986252784729
# 360
# 0.4226962924003601
# 360
# 0.43038442730903625
# 360
# 0.43310579657554626
# 360
# 0.12680967152118683
# 360
# 0.4248969852924347
# 360
# 0.4131106436252594
# 360
# 0.14633207023143768
# 360
# 0.17294847965240479
# 360
# 0.3699268102645874
# 360
# 0.375955194234848
# 360
# 0.36370572447776794
# 360
# 0.3515944480895996
# 360
# 0.15516602993011475
# 360
# 0.1854126900434494
# 360
# 0.12353073805570602
# 360
# 0.11999999731779099
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 38
#      37     node = Roamer()
# ---> 38     rclpy.spin(node)
#      39 finally:
#
# File /opt/ros/humble/local/lib/python3.10/dist-packages/rclpy/__init__.py:222, in spin(node, executor)
#     221     while executor.context.ok():
# --> 222         executor.spin_once()
#     223 finally:
#
# File /opt/ros/humble/local/lib/python3.10/dist-packages/rclpy/executors.py:705, in SingleThreadedExecutor.spin_once(self, timeout_sec)
#     704 try:
# --> 705     handler, entity, node = self.wait_for_ready_callbacks(timeout_sec=timeout_sec)
#     706 except ShutdownException:
#
# File /opt/ros/humble/local/lib/python3.10/dist-packages/rclpy/executors.py:691, in Executor.wait_for_ready_callbacks(self, *args, **kwargs)
#     690 try:
# --> 691     return next(self._cb_iter)
#     692 except StopIteration:
#     693     # Generator ran out of work
#
# File /opt/ros/humble/local/lib/python3.10/dist-packages/rclpy/executors.py:588, in Executor._wait_for_ready_callbacks(self, timeout_sec, nodes, condition)
#     587 # Wait for something to become ready
# --> 588 wait_set.wait(timeout_nsec)
#     589 if self._is_shutdown:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# RCLError                                  Traceback (most recent call last)
# Cell In[3], line 43
#      41     node.destroy_node()
#      42 finally:
# ---> 43     rclpy.shutdown()
#
# File /opt/ros/humble/local/lib/python3.10/dist-packages/rclpy/__init__.py:126, in shutdown(context, uninstall_handlers)
#     113 def shutdown(*, context: Context = None, uninstall_handlers: Optional[bool] = None) -> None:
#     114     """
#     115     Shutdown a previously initialized context.
#     116
#    (...)
#     124         If not, signal handlers won't be uninstalled.
#     125     """
# --> 126     _shutdown(context=context)
#     127     if (
#     128         uninstall_handlers or (
#     129             uninstall_handlers is None and (
#     130                 context is None or context is get_default_context()))
#     131     ):
#     132         uninstall_signal_handlers()
#
# File /opt/ros/humble/local/lib/python3.10/dist-packages/rclpy/utilities.py:58, in shutdown(context)
#      56 if context is None:
#      57     context = get_default_context(shutting_down=True)
# ---> 58 return context.shutdown()
#
# File /opt/ros/humble/local/lib/python3.10/dist-packages/rclpy/context.py:102, in Context.shutdown(self)
#     100     raise RuntimeError('Context must be initialized before it can be shutdown')
#     101 with self.__context, self._lock:
# --> 102     self.__context.shutdown()
#     103     self._call_on_shutdown_callbacks()
#     104     self._logging_fini()
#
# RCLError: failed to shutdown: rcl_shutdown already called on the given context, at ./src/rcl/init.c:241
